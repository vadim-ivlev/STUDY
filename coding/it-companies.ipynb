# %%
import pandas as pd

# %%
p=pd.read_html('http://www.cnews.ru/reviews/rynok_it_itogi_2016/review_table/0df09b79ae24ab68be9bd003fa16a26de1faa3ea')

# %%
с=p[1]

# %%
pd.to_numeric(c, errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-514212c8296f> in <module>()
# ----> 1 pd.to_numeric(c, errors='coerce')
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     118         values = np.array([arg], dtype='O')
#     119     elif getattr(arg, 'ndim', 1) > 1:
# --> 120         raise TypeError('arg must be a list, tuple, 1-d array, or Series')
#     121     else:
#     122         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %%
cc=c.infer_objects()
cc.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# 11    object
# 12    object
# 13    object
# dtype: object

# %%
cc.sort_values([5])
# Out:
#          0       1                                        2   \
# 77       77      67                                  Неолант
# 76       76      88                     Корус консалтинг СНГ
# 75       75      87                      First Line Software
# 74       74      75                                    Аскон
# 73       73      80                 Центр речевых технологий
# 72       72      74                                 Omnicomm
# 71       71      70                          Импульс Телеком
# 70       70      63                              Интерпроком
# 69       69      71                              ДиалогНаука
# 68       68       –                                     Кито
# 67       67      73                                InfoWatch
# 66       66      59                                    Форус
# 65       65      61                                    Сонет
# 64       64      58                                 Ангстрем
# ...

# %%
p[1]
# Out:
#          0       1                                        2   \
# 0    № 2016  № 2015                        Название компании
# 1         1       1                                      НКК
# 2         2       2                                    Ланит
# 3         3       –                                    Epam*
# 4         4       5                                 Softline
# 5         5       4                                Техносерв
# 6         6       3                 Газпром Автоматизация***
# 7         7       7                                 Luxoft *
# 8         8       6                 Лаборатория Касперского*
# 9         9       8                                     1С**
# 10       10       9       ITG (Inline Technologies Group)(3)
# 11       11      11                                  Ай-Теко
# 12       12      12                                     Крок
# 13       13      13                   Cognitive Technologies
# ...
